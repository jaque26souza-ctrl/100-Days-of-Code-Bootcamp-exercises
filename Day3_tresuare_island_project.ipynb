# %% [markdown]
# <a href="https://colab.research.google.com/github/jaque26souza-ctrl/100-Days-of-Code-Bootcamp-exercises/blob/main/Day3_tresuare_island_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TRESUARE ISLAND PROJECT
#
# ### 🏝️ Dia 03 - Treasure Island
#
# Um jogo de texto interativo baseado em tomada de decisões, onde o objetivo é navegar por uma ilha e encontrar o tesouro perdido.
#
# #### 🎯 Conceitos Aprendidos
# * Estruturas condicionais avançadas (`if`, `elif`, `else`)
# * Condicionais aninhadas (*nested conditionals*)
# * Manipulação e padronização de strings (`.lower()`)
# * Operadores lógicos (`and`, `or`, `not`)
#
# #### 🗺️ Fluxo de Decisões do Jogo
# ![diagrama dia 3.png](data:image/png;base64,...)

# %%
#           __..-----')
#        ,.--._ .-'_..--...-'
#       '-"'. _/_ /  ..--''""'-.
#       _.--""...:._:(_ ..:"::. \
#    .-' ..::--""_(##)#)"':. \ \)    \ _|_ /
#   /_:-:'/  :__(##)##)    ): )   '-./'   '\.-'
#   "  / |  :' :/""\///)  /:.'    --(       )--
#     / :( :( :(   (#//)  "       .-'\.___./'-.
#    / :/|\ :\_:\   \#//\            /  |  \
#    |:/ | ""--':\   (#//)              '
#    \/  \ :|  \ :\  (#//)
#         \:\   '.':. \#//\
#          ':|    "--'(#///)
#                     (#///)
#                     (#///)         ___/""\
#                      \#///\           oo##
#                      (##///)         `-6 #
#                      (##///)          ,'`.
#                      (##///)         // `.\
#                      (##///)        ||o   \\
#                       \##///\        \-+--//
#                       (###///)       :_|_(/
#                       (sjw////)__...--:: :...__
#                       (#/::'''        :: :     ""--.._
#                  __..-'''           __;: :            "-._
#          __..--""                  `---/ ;                '._
# ___..--""                             `-'                    "-..___
#   (_ ""---....___                                     __...--"" _)
#     """--...  ___"""""-----......._______......----"""     --"""
#                   """"       ---.....   ___....----






print("Welcome to Treasure Island Game!!")
print("Your mission is to find the treasure")

road = input("You're at a cross road. Where do you want to go? Type left or right: ").lower()

if road == "left":
    wait = input("You've come to a lake. There is an island in the middle of the lake. Type 'wait' to wait for a boat. Type 'swim' to swim across: ").lower()

    if wait == "wait":
        door = input("You arrive at the island unharmed. There is a house with 3 doors. One red, one yellow and one blue. Which door do you choose? ").lower()

        if door == "yellow":
            print("You found the treasure! You Win!")
        elif door == "red":
            print("It's a room full of fire. Game Over!!")
        elif door == "blue":
            print("You enter a room of beasts. Game Over!!")
        else:
            print("You chose a door that doesn't exist. Game Over!!")

    else:
        print("You get attacked by an angry trout. Game Over!!")

else:
    print("You fell into a hole. Game Over!!")
# Out:
# Welcome to Treasure Island Game!!
# Your mission is to find the treasure
# You're at a cross road. Where do you want to go? Type left or right: left
# You've come to a lake. There is an island in the middle of the lake. Type 'wait' to wait for a boat. Type 'swim' to swim across: wait
# You arrive at the island unharmed. There is a house with 3 doors. One red, one yellow and one blue. Which door do you choose? red
# It's a room full of fire. Game Over!!

# %% [markdown]
# # **Python Pizza Deliveries**!

# %%
print("Welcome to Python Pizza Deliveries!")
size = input("What size pizza do you want? S, M or L: ")
bill = 0

if size == "S":
    bill += 15
    print("Small pizza is $15.")
elif size == "M":
    bill += 20
    print("Medium pizza is $20.")
elif size == "L":
    bill += 25
    print("Large pizza is $25.")
else:
    print("Please enter a valid size.")

pepperoni = input("Do you want pepperoni on your pizza? Y or N: ")
if pepperoni == "Y":
    if size == "S":
        bill += 2
        print("Pepperoni on small pizza is $2.")
    elif size == "M" or size == "L":
        bill += 3
        print("Pepperoni on large pizza is $3.")


extra_cheese = input("Do you want extra cheese? Y or N: ")
if extra_cheese == "Y":
    bill += 1
    print("Extra cheese is $1.")

print(f"Your final bill is {bill}")
# Out:
# Welcome to Python Pizza Deliveries!
# What size pizza do you want? S, M or L: M
# Medium pizza is $20.
# Do you want pepperoni on your pizza? Y or N: Y
# Pepperoni on large pizza is $3.
# Do you want extra cheese? Y or N: Y
# Extra cheese is $1.
# Your final bill is 24
