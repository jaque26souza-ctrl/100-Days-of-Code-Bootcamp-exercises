# %% [markdown]
# <a href="https://colab.research.google.com/github/jaque26souza-ctrl/100-Days-of-Code-Bootcamp-exercises/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Band Name Generator Project

# %%
## Criando um gerador de nome de banda
city = input("What's the name of the city you grew up in? ")
pet = input("What's your pet's name? ")
print("Your band's name could be " + city + " " + pet)
# Out:
# What's the name of the city you grew up in? Black River
# What's your pet's name? Marceline
# Your band's name could be Black River Marceline
