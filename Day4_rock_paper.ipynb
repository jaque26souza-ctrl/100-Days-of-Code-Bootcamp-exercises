# %% [markdown]
# <a href="https://colab.research.google.com/github/jaque26souza-ctrl/100-Days-of-Code-Bootcamp-exercises/blob/main/Day4_rock_paper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 4 - Rock, Papers and Scissors
